# %%
# %load_ext autoreload
# %autoreload 2

from folde.util import load_checkpointed_model_eval, convert_compaign_result_collection_to_df, DMS_SHORTNAMES

results = load_checkpointed_model_eval(
    'notebooks/jacob/model_evals/',
    '250711-folde-testset-wCL',
    []
)
mutant_df, round_metrics_df = convert_compaign_result_collection_to_df(results)
round_metrics_df['dms_shortname'] = round_metrics_df.dms_id.apply(lambda x: DMS_SHORTNAMES[x])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading results for DMSs: {'MET_HUMAN_Estevam_2023', 'AMIE_PSEAE_Wrenbeck_2017', 'CAS9_STRP1_Spencer_2017_positive', 'MK01_HUMAN_Brenan_2016', 'KCNJ2_MOUSE_Coyote-Maestas_2022_function', 'P53_HUMAN_Giacomelli_2018_Null_Nutlin', 'S22A1_HUMAN_Yee_2023_activity', 'P53_HUMAN_Giacomelli_2018_WT_Nutlin', 'SC6A4_HUMAN_Young_2021', 'PTEN_HUMAN_Mighell_2018', 'MTHR_HUMAN_Weile_2021', 'LGK_LIPST_Klesmith_2015', 'KKA2_KLEPN_Melnikov_2014', 'ADRB2_HUMAN_Jones_2020', 'PPARG_HUMAN_Majithia_2016'}

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from statannotations.Annotator import Annotator

# method1 = 'FolDE-Random-RandomForestCtrl'
methods = [
    'Random',
    'EvolvePro',
    'FolDE'
]

METRIC = 'held_out_10pct_recall'  # 'best_activity_this_round'  # held_out_activity_spearman
LINE_ALPHA = 0.1

YRANGE = (0.0, 0.1)

def plot_aggregate_comparison(ax, data_df):
    sns.boxplot( # stripplot
        data=data_df,
        x="config_name",
        y=METRIC,
        hue="config_name",
        dodge=True,
        # jitter=True,
        # alpha=0.7,
        order=methods,
        hue_order=methods,
        ax=ax
    )

    for ii, (method1, method2) in enumerate(zip(methods[:-1], methods[1:])):
        for sim_id in data_df['sim_num'].unique():
            subset = data_df[
                (data_df['sim_num'] == sim_id)
            ].set_index('config_name')
            y1 = subset.loc[method1, METRIC]
            y2 = subset.loc[method2, METRIC]
            # Get the x position for this dms_shortname
            # Get the x positions for the two hues (dodge)
            ax.plot(
                [-0.3 + ii* 1.3, 1.0 + ii * 1.3],
                [y1, y2],
                color='gray',
                alpha=LINE_ALPHA,
                zorder=1
            )

    ax1_pairs = [
        ((mleft,), (mright,)) for mleft, mright in zip(methods[:-1], methods[1:])
    ]

    # ax1_pairs = [
    #     ((methods[0], ), (methods[1], )),
    #     ((methods[1], ), (methods[2], )),
    # ]
    annot1 = Annotator(
        ax,
        ax1_pairs,
        data=data_df,
        x='config_name',
        y=METRIC,
        hue="config_name",
        order=methods,
        hue_order=methods
    )
    annot1.configure(test='t-test_paired', verbose=2)  #'t-test_ind'  Mann-Whitney
    annot1.apply_test()
    annot1.annotate()

    ax.set_ylabel('')
    ax.set_xlabel('')

def plot_breakdown_comparison(ax, data_df):
    sns.boxplot(
        data=data_df,
        x="dms_shortname",
        y=METRIC,
        hue="config_name",
        dodge=True,
        # jitter=True,
        # alpha=0.7,
        order=ordered_dms,
        hue_order=methods,
        ax=ax
    )

    pairs = []

    # Connect the two config points for each dms_shortname
    for dms in ordered_dms:
        for ii, (method1, method2) in enumerate(zip(methods[:-1], methods[1:])):
            pairs.append(
                ((dms, method1), (dms, method2))
            )

            for sim_id in data_df['sim_num'].unique():
                subset = data_df[
                    (data_df['dms_shortname'] == dms) &
                    (data_df['sim_num'] == sim_id)
                ].set_index('config_name')
                y1 = subset.loc[method1, METRIC]
                y2 = subset.loc[method2, METRIC]
                # Get the x position for this dms_shortname
                x_pos = ordered_dms.index(dms)
                # Get the x positions for the two hues (dodge)
                offsets = [-0.2 + ii * 0.2, 0.0 + ii * 0.2]  # adjust if your dodge is different
                ax.plot(
                    [x_pos + offsets[0], x_pos + offsets[1]],
                    [y1, y2],
                    color='gray',
                    alpha=LINE_ALPHA,
                    zorder=1
                )


    annot = Annotator(
        ax,
        pairs,
        data=data_df,
        x="dms_shortname",
        y=METRIC,
        hue="config_name",
        comparisons_correction='bonferroni',
        order=ordered_dms,
        hue_order=methods
    )
    annot.configure(test='t-test_paired', verbose=2)  #'t-test_ind'  Mann-Whitney
    annot.apply_test()
    annot.annotate()

    ax.set_ylabel('')
    ax.set_xlabel('')




fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(12, 7), dpi=300, width_ratios=(1,5), sharey='row')

for ROUND, (leftax, rightax) in [(1, (ax1, ax2)), (2, (ax3, ax4)), (3, (ax5, ax6))]:
    comparison_df = round_metrics_df.copy()
    comparison_df['config_name'] = comparison_df.config_name.apply(lambda x: {
        'FolDE-random': 'Random',
        'FolDE-Random-RandomForestCtrl': 'EvolvePro',
        'FolDE-base': 'FolDE'
    }.get(x, x))
    comparison_df = comparison_df[
        comparison_df.config_name.isin(methods) & (round_metrics_df.round_num == ROUND)
    ].sort_values(['dms_id', 'config_name', 'sim_num']).copy()

    # Sort dms_shortname for consistent x-axis order
    ordered_dms = sorted(comparison_df['dms_shortname'].unique())

    plot_aggregate_comparison(leftax, comparison_df)
    plot_breakdown_comparison(rightax, comparison_df)

for ax in [ax1, ax2, ax3, ax4]:
    ax.set_xticks([])
# for ax in [ax2, ax4, ax6]:
#     ax.set_yticks([])
# for ax in [ax1, ax2, ax3, ax4, ax5, ax6]:
#     ax.set_ylim(YRANGE[0], YRANGE[1])
# for ax in [ax4, ax6]:
#     ax.set_legend(False)

for ax in [ax1, ax3, ax5]:
    if METRIC == 'held_out_1pct_recall':
        ax.set_ylabel('Held Out 1% Recall')
    elif METRIC == 'held_out_10pct_recall':
        ax.set_ylabel('Held Out 10% Recall')
    else:
        ax.set_ylabel(METRIC)

ax5.set_xlabel('Workflow')
ax6.set_xlabel('ProteinGym Target')

# plt.title(f'Performance Difference At Round {ROUND}')
plt.xticks(rotation=15, ha="right")
plt.legend(title='config_name')
plt.tight_layout()
plt.show()
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Random vs. EvolvePro: t-test paired samples, P_val:nan t=nan
# EvolvePro vs. FolDE: t-test paired samples, P_val:5.148e-33 t=-1.555e+01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMIE_PSEAE_Random vs. AMIE_PSEAE_EvolvePro: t-test paired samples, P_val:nan t=nan
# AMIE_PSEAE_EvolvePro vs. AMIE_PSEAE_FolDE: t-test paired samples, P_val:7.414e-07 t=-1.205e+01
# CAS9_STRP1_Random vs. CAS9_STRP1_EvolvePro: t-test paired samples, P_val:nan t=nan
# CAS9_STRP1_EvolvePro vs. CAS9_STRP1_FolDE: t-test paired samples, P_val:8.674e-01 t=1.718e-01
# KCNJ2_MOUSE_Random vs. KCNJ2_MOUSE_EvolvePro: t-test paired samples, P_val:nan t=nan
# KCNJ2_MOUSE_EvolvePro vs. KCNJ2_MOUSE_FolDE: t-test paired samples, P_val:1.819e-06 t=-1.084e+01
# KKA2_KLEPN_Random vs. KKA2_KLEPN_EvolvePro: t-test paired samples, P_val:nan t=nan
# KKA2_KLEPN_EvolvePro vs. KKA2_KLEPN_FolDE: t-test paired samples, P_val:3.332e-10 t=-2.903e+01
# LGK_LIPST_Random vs. LGK_LIPST_EvolvePro: t-test paired samples, P_val:nan t=nan
# LGK_LIPST_EvolvePro vs. LGK_LIPST_FolDE: t-test paired samples, P_val:4.134e-09 t=-2.186e+01
# MET_HUMAN_Random vs. MET_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# MET_HUMAN_EvolvePro vs. MET_HUMAN_FolDE: t-test paired samples, P_val:1.344e-07 t=-1.470e+01
# MK01_HUMAN_Random vs. MK01_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# MK01_HUMAN_EvolvePro vs. MK01_HUMAN_FolDE: t-test paired samples, P_val:9.452e-01 t=7.073e-02
# MTHR_HUMAN_Random vs. MTHR_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# ADRB2_HUMAN_Random vs. ADRB2_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# ADRB2_HUMAN_EvolvePro vs. ADRB2_HUMAN_FolDE: t-test paired samples, P_val:4.505e-07 t=-1.278e+01
# MTHR_HUMAN_EvolvePro vs. MTHR_HUMAN_FolDE: t-test paired samples, P_val:1.546e-02 t=-2.980e+00
# P53_HUMAN_Null_Random vs. P53_HUMAN_Null_EvolvePro: t-test paired samples, P_val:nan t=nan
# P53_HUMAN_Null_EvolvePro vs. P53_HUMAN_Null_FolDE: t-test paired samples, P_val:3.940e-02 t=-2.408e+00
# P53_HUMAN_WT_Random vs. P53_HUMAN_WT_EvolvePro: t-test paired samples, P_val:nan t=nan
# P53_HUMAN_WT_EvolvePro vs. P53_HUMAN_WT_FolDE: t-test paired samples, P_val:4.023e-01 t=-8.789e-01
# PPARG_HUMAN_Random vs. PPARG_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# PPARG_HUMAN_EvolvePro vs. PPARG_HUMAN_FolDE: t-test paired samples, P_val:1.006e-05 t=-8.821e+00
# PTEN_HUMAN_Random vs. PTEN_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# PTEN_HUMAN_EvolvePro vs. PTEN_HUMAN_FolDE: t-test paired samples, P_val:3.908e-07 t=-1.299e+01
# S22A1_HUMAN_Random vs. S22A1_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# S22A1_HUMAN_EvolvePro vs. S22A1_HUMAN_FolDE: t-test paired samples, P_val:1.243e-09 t=-2.503e+01
# SC6A4_HUMAN_Random vs. SC6A4_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# SC6A4_HUMAN_EvolvePro vs. SC6A4_HUMAN_FolDE: t-test paired samples, P_val:4.661e-10 t=-2.795e+01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Random vs. EvolvePro: t-test paired samples, P_val:9.222e-32 t=-1.507e+01
# EvolvePro vs. FolDE: t-test paired samples, P_val:9.494e-07 t=-5.115e+00
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMIE_PSEAE_Random vs. AMIE_PSEAE_EvolvePro: t-test paired samples, P_val:4.508e-03 t=-3.757e+00
# AMIE_PSEAE_EvolvePro vs. AMIE_PSEAE_FolDE: t-test paired samples, P_val:1.311e-05 t=-8.538e+00
# CAS9_STRP1_Random vs. CAS9_STRP1_EvolvePro: t-test paired samples, P_val:8.524e-02 t=-1.933e+00
# CAS9_STRP1_EvolvePro vs. CAS9_STRP1_FolDE: t-test paired samples, P_val:4.433e-01 t=8.018e-01
# KCNJ2_MOUSE_Random vs. KCNJ2_MOUSE_EvolvePro: t-test paired samples, P_val:1.003e-01 t=-1.831e+00
# KCNJ2_MOUSE_EvolvePro vs. KCNJ2_MOUSE_FolDE: t-test paired samples, P_val:4.759e-06 t=-9.662e+00
# KKA2_KLEPN_Random vs. KKA2_KLEPN_EvolvePro: t-test paired samples, P_val:1.363e-06 t=-1.122e+01
# KKA2_KLEPN_EvolvePro vs. KKA2_KLEPN_FolDE: t-test paired samples, P_val:4.309e-01 t=-8.246e-01
# LGK_LIPST_Random vs. LGK_LIPST_EvolvePro: t-test paired samples, P_val:1.639e-05 t=-8.305e+00
# LGK_LIPST_EvolvePro vs. LGK_LIPST_FolDE: t-test paired samples, P_val:1.800e-03 t=-4.369e+00
# MET_HUMAN_Random vs. MET_HUMAN_EvolvePro: t-test paired samples, P_val:1.012e-04 t=-6.583e+00
# MET_HUMAN_EvolvePro vs. MET_HUMAN_FolDE: t-test paired samples, P_val:7.854e-01 t=2.806e-01
# MK01_HUMAN_Random vs. MK01_HUMAN_EvolvePro: t-test paired samples, P_val:7.363e-01 t=-3.474e-01
# MK01_HUMAN_EvolvePro vs. MK01_HUMAN_FolDE: t-test paired samples, P_val:3.125e-02 t=-2.549e+00
# MTHR_HUMAN_Random vs. MTHR_HUMAN_EvolvePro: t-test paired samples, P_val:9.652e-03 t=-3.272e+00
# ADRB2_HUMAN_Random vs. ADRB2_HUMAN_EvolvePro: t-test paired samples, P_val:1.447e-06 t=-1.114e+01
# ADRB2_HUMAN_EvolvePro vs. ADRB2_HUMAN_FolDE: t-test paired samples, P_val:5.512e-03 t=-3.627e+00
# MTHR_HUMAN_EvolvePro vs. MTHR_HUMAN_FolDE: t-test paired samples, P_val:9.481e-01 t=6.697e-02
# P53_HUMAN_Null_Random vs. P53_HUMAN_Null_EvolvePro: t-test paired samples, P_val:3.336e-04 t=-5.602e+00
# P53_HUMAN_Null_EvolvePro vs. P53_HUMAN_Null_FolDE: t-test paired samples, P_val:1.459e-01 t=1.592e+00
# P53_HUMAN_WT_Random vs. P53_HUMAN_WT_EvolvePro: t-test paired samples, P_val:1.249e-03 t=-4.623e+00
# P53_HUMAN_WT_EvolvePro vs. P53_HUMAN_WT_FolDE: t-test paired samples, P_val:8.042e-03 t=3.387e+00
# PPARG_HUMAN_Random vs. PPARG_HUMAN_EvolvePro: t-test paired samples, P_val:1.625e-03 t=-4.439e+00
# PPARG_HUMAN_EvolvePro vs. PPARG_HUMAN_FolDE: t-test paired samples, P_val:1.761e-05 t=-8.232e+00
# PTEN_HUMAN_Random vs. PTEN_HUMAN_EvolvePro: t-test paired samples, P_val:7.168e-05 t=-6.887e+00
# PTEN_HUMAN_EvolvePro vs. PTEN_HUMAN_FolDE: t-test paired samples, P_val:8.340e-01 t=-2.157e-01
# S22A1_HUMAN_Random vs. S22A1_HUMAN_EvolvePro: t-test paired samples, P_val:7.935e-05 t=-6.797e+00
# S22A1_HUMAN_EvolvePro vs. S22A1_HUMAN_FolDE: t-test paired samples, P_val:2.608e-05 t=-7.837e+00
# SC6A4_HUMAN_Random vs. SC6A4_HUMAN_EvolvePro: t-test paired samples, P_val:3.475e-05 t=-7.558e+00
# SC6A4_HUMAN_EvolvePro vs. SC6A4_HUMAN_FolDE: t-test paired samples, P_val:1.332e-02 t=-3.072e+00
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Random vs. EvolvePro: t-test paired samples, P_val:6.098e-31 t=-1.476e+01
# EvolvePro vs. FolDE: t-test paired samples, P_val:4.388e-04 t=-3.596e+00
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMIE_PSEAE_Random vs. AMIE_PSEAE_EvolvePro: t-test paired samples, P_val:2.960e-04 t=-5.695e+00
# AMIE_PSEAE_EvolvePro vs. AMIE_PSEAE_FolDE: t-test paired samples, P_val:2.601e-03 t=-4.119e+00
# CAS9_STRP1_Random vs. CAS9_STRP1_EvolvePro: t-test paired samples, P_val:5.007e-01 t=-7.016e-01
# CAS9_STRP1_EvolvePro vs. CAS9_STRP1_FolDE: t-test paired samples, P_val:7.316e-01 t=-3.539e-01
# KCNJ2_MOUSE_Random vs. KCNJ2_MOUSE_EvolvePro: t-test paired samples, P_val:7.741e-02 t=-1.993e+00
# KCNJ2_MOUSE_EvolvePro vs. KCNJ2_MOUSE_FolDE: t-test paired samples, P_val:6.474e-04 t=-5.097e+00
# KKA2_KLEPN_Random vs. KKA2_KLEPN_EvolvePro: t-test paired samples, P_val:6.154e-05 t=-7.025e+00
# KKA2_KLEPN_EvolvePro vs. KKA2_KLEPN_FolDE: t-test paired samples, P_val:7.433e-02 t=-2.018e+00
# LGK_LIPST_Random vs. LGK_LIPST_EvolvePro: t-test paired samples, P_val:2.661e-04 t=-5.780e+00
# LGK_LIPST_EvolvePro vs. LGK_LIPST_FolDE: t-test paired samples, P_val:1.740e-04 t=-6.124e+00
# MET_HUMAN_Random vs. MET_HUMAN_EvolvePro: t-test paired samples, P_val:1.399e-05 t=-8.470e+00
# MET_HUMAN_EvolvePro vs. MET_HUMAN_FolDE: t-test paired samples, P_val:4.860e-01 t=7.264e-01
# MK01_HUMAN_Random vs. MK01_HUMAN_EvolvePro: t-test paired samples, P_val:3.952e-03 t=-3.842e+00
# MK01_HUMAN_EvolvePro vs. MK01_HUMAN_FolDE: t-test paired samples, P_val:7.051e-01 t=3.907e-01
# MTHR_HUMAN_Random vs. MTHR_HUMAN_EvolvePro: t-test paired samples, P_val:1.285e-03 t=-4.603e+00
# ADRB2_HUMAN_Random vs. ADRB2_HUMAN_EvolvePro: t-test paired samples, P_val:4.113e-03 t=-3.816e+00
# ADRB2_HUMAN_EvolvePro vs. ADRB2_HUMAN_FolDE: t-test paired samples, P_val:1.987e-04 t=-6.016e+00
# MTHR_HUMAN_EvolvePro vs. MTHR_HUMAN_FolDE: t-test paired samples, P_val:1.527e-01 t=1.562e+00
# P53_HUMAN_Null_Random vs. P53_HUMAN_Null_EvolvePro: t-test paired samples, P_val:3.227e-04 t=-5.627e+00
# P53_HUMAN_Null_EvolvePro vs. P53_HUMAN_Null_FolDE: t-test paired samples, P_val:1.442e-02 t=3.023e+00
# P53_HUMAN_WT_Random vs. P53_HUMAN_WT_EvolvePro: t-test paired samples, P_val:9.653e-04 t=-4.806e+00
# P53_HUMAN_WT_EvolvePro vs. P53_HUMAN_WT_FolDE: t-test paired samples, P_val:3.551e-02 t=2.471e+00
# PPARG_HUMAN_Random vs. PPARG_HUMAN_EvolvePro: t-test paired samples, P_val:7.001e-05 t=-6.908e+00
# PPARG_HUMAN_EvolvePro vs. PPARG_HUMAN_FolDE: t-test paired samples, P_val:5.541e-03 t=-3.624e+00
# PTEN_HUMAN_Random vs. PTEN_HUMAN_EvolvePro: t-test paired samples, P_val:7.842e-07 t=-1.197e+01
# PTEN_HUMAN_EvolvePro vs. PTEN_HUMAN_FolDE: t-test paired samples, P_val:6.930e-01 t=4.077e-01
# S22A1_HUMAN_Random vs. S22A1_HUMAN_EvolvePro: t-test paired samples, P_val:2.348e-04 t=-5.880e+00
# S22A1_HUMAN_EvolvePro vs. S22A1_HUMAN_FolDE: t-test paired samples, P_val:1.606e-04 t=-6.191e+00
# SC6A4_HUMAN_Random vs. SC6A4_HUMAN_EvolvePro: t-test paired samples, P_val:2.697e-06 t=-1.034e+01
# SC6A4_HUMAN_EvolvePro vs. SC6A4_HUMAN_FolDE: t-test paired samples, P_val:2.274e-02 t=-2.743e+00
