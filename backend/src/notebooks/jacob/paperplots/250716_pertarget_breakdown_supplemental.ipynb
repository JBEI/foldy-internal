# %%
# %load_ext autoreload
# %autoreload 2

from folde.util import load_checkpointed_model_eval, convert_compaign_result_collection_to_df, DMS_SHORTNAMES

results = load_checkpointed_model_eval(
    'notebooks/jacob/model_evals/',
    '250711-folde-testset-wCL',
    []
)
mutant_df, round_metrics_df = convert_compaign_result_collection_to_df(results)
round_metrics_df['dms_shortname'] = round_metrics_df.dms_id.apply(lambda x: DMS_SHORTNAMES[x])
# Out:
# Loading results for DMSs: {'KCNJ2_MOUSE_Coyote-Maestas_2022_function', 'PTEN_HUMAN_Mighell_2018', 'LGK_LIPST_Klesmith_2015', 'S22A1_HUMAN_Yee_2023_activity', 'MK01_HUMAN_Brenan_2016', 'P53_HUMAN_Giacomelli_2018_WT_Nutlin', 'MET_HUMAN_Estevam_2023', 'MTHR_HUMAN_Weile_2021', 'CAS9_STRP1_Spencer_2017_positive', 'ADRB2_HUMAN_Jones_2020', 'SC6A4_HUMAN_Young_2021', 'AMIE_PSEAE_Wrenbeck_2017', 'PPARG_HUMAN_Majithia_2016', 'KKA2_KLEPN_Melnikov_2014', 'P53_HUMAN_Giacomelli_2018_Null_Nutlin'}

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from statannotations.Annotator import Annotator

# method1 = 'FolDE-Random-RandomForestCtrl'
methods = [
    'Random',
    'EvolvePro',
    'FolDE'
]

METRIC = 'held_out_1pct_auc'  # 'best_activity_this_round'  # held_out_activity_spearman
LINE_ALPHA = 0.1

YRANGE = (0.0, 0.1)

def plot_aggregate_comparison(ax, data_df):
    sns.boxplot( # stripplot
        data=data_df,
        x="config_name",
        y=METRIC,
        hue="config_name",
        dodge=True,
        # jitter=True,
        # alpha=0.7,
        order=methods,
        hue_order=methods,
        ax=ax
    )

    for ii, (method1, method2) in enumerate(zip(methods[:-1], methods[1:])):
        for sim_id in data_df['sim_num'].unique():
            subset = data_df[
                (data_df['sim_num'] == sim_id)
            ].set_index('config_name')
            y1 = subset.loc[method1, METRIC]
            y2 = subset.loc[method2, METRIC]
            # Get the x position for this dms_shortname
            # Get the x positions for the two hues (dodge)
            ax.plot(
                [-0.3 + ii* 1.3, 1.0 + ii * 1.3],
                [y1, y2],
                color='gray',
                alpha=LINE_ALPHA,
                zorder=1
            )

    ax1_pairs = [
        ((mleft,), (mright,)) for mleft, mright in zip(methods[:-1], methods[1:])
    ]

    # ax1_pairs = [
    #     ((methods[0], ), (methods[1], )),
    #     ((methods[1], ), (methods[2], )),
    # ]
    annot1 = Annotator(
        ax,
        ax1_pairs,
        data=data_df,
        x='config_name',
        y=METRIC,
        hue="config_name",
        order=methods,
        hue_order=methods
    )
    annot1.configure(test='t-test_paired', verbose=2)  #'t-test_ind'  Mann-Whitney
    annot1.apply_test()
    annot1.annotate()

    ax.set_ylabel('')
    ax.set_xlabel('')

def plot_breakdown_comparison(ax, data_df):
    sns.boxplot(
        data=data_df,
        x="dms_shortname",
        y=METRIC,
        hue="config_name",
        dodge=True,
        # jitter=True,
        # alpha=0.7,
        order=ordered_dms,
        hue_order=methods,
        ax=ax
    )

    pairs = []

    # Connect the two config points for each dms_shortname
    for dms in ordered_dms:
        for ii, (method1, method2) in enumerate(zip(methods[:-1], methods[1:])):
            pairs.append(
                ((dms, method1), (dms, method2))
            )

            for sim_id in data_df['sim_num'].unique():
                subset = data_df[
                    (data_df['dms_shortname'] == dms) &
                    (data_df['sim_num'] == sim_id)
                ].set_index('config_name')
                y1 = subset.loc[method1, METRIC]
                y2 = subset.loc[method2, METRIC]
                # Get the x position for this dms_shortname
                x_pos = ordered_dms.index(dms)
                # Get the x positions for the two hues (dodge)
                offsets = [-0.2 + ii * 0.2, 0.0 + ii * 0.2]  # adjust if your dodge is different
                ax.plot(
                    [x_pos + offsets[0], x_pos + offsets[1]],
                    [y1, y2],
                    color='gray',
                    alpha=LINE_ALPHA,
                    zorder=1
                )


    annot = Annotator(
        ax,
        pairs,
        data=data_df,
        x="dms_shortname",
        y=METRIC,
        hue="config_name",
        comparisons_correction='bonferroni',
        order=ordered_dms,
        hue_order=methods
    )
    annot.configure(test='t-test_paired', verbose=2)  #'t-test_ind'  Mann-Whitney
    annot.apply_test()
    annot.annotate()

    ax.set_ylabel('')
    ax.set_xlabel('')




fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(12, 7), dpi=300, width_ratios=(1,5), sharey='row')

for ROUND, (leftax, rightax) in [(1, (ax1, ax2)), (2, (ax3, ax4)), (3, (ax5, ax6))]:
    comparison_df = round_metrics_df.copy()
    comparison_df['config_name'] = comparison_df.config_name.apply(lambda x: {
        'FolDE-random': 'Random',
        'FolDE-Random-RandomForestCtrl': 'EvolvePro',
        'FolDE-base': 'FolDE'
    }.get(x, x))
    comparison_df = comparison_df[
        comparison_df.config_name.isin(methods) & (round_metrics_df.round_num == ROUND)
    ].sort_values(['dms_id', 'config_name', 'sim_num']).copy()

    # Sort dms_shortname for consistent x-axis order
    ordered_dms = sorted(comparison_df['dms_shortname'].unique())

    plot_aggregate_comparison(leftax, comparison_df)
    plot_breakdown_comparison(rightax, comparison_df)

for ax in [ax1, ax2, ax3, ax4]:
    ax.set_xticks([])
# for ax in [ax2, ax4, ax6]:
#     ax.set_yticks([])
# for ax in [ax1, ax2, ax3, ax4, ax5, ax6]:
#     ax.set_ylim(YRANGE[0], YRANGE[1])
# for ax in [ax4, ax6]:
#     ax.set_legend(False)

for ax in [ax1, ax3, ax5]:
    if METRIC == 'held_out_1pct_recall':
        ax.set_ylabel('Held Out 1% Recall')
    elif METRIC == 'held_out_10pct_recall':
        ax.set_ylabel('Held Out 10% Recall')
    else:
        ax.set_ylabel(METRIC)

ax5.set_xlabel('Workflow')
ax6.set_xlabel('ProteinGym Target')

# plt.title(f'Performance Difference At Round {ROUND}')
plt.xticks(rotation=15, ha="right")
plt.legend(title='config_name')
plt.tight_layout()
plt.show()
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Random vs. EvolvePro: t-test paired samples, P_val:nan t=nan
# EvolvePro vs. FolDE: t-test paired samples, P_val:2.943e-33 t=-1.565e+01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMIE_PSEAE_Random vs. AMIE_PSEAE_EvolvePro: t-test paired samples, P_val:nan t=nan
# AMIE_PSEAE_EvolvePro vs. AMIE_PSEAE_FolDE: t-test paired samples, P_val:3.007e-07 t=-1.339e+01
# CAS9_STRP1_Random vs. CAS9_STRP1_EvolvePro: t-test paired samples, P_val:nan t=nan
# CAS9_STRP1_EvolvePro vs. CAS9_STRP1_FolDE: t-test paired samples, P_val:3.400e-03 t=-3.941e+00
# KCNJ2_MOUSE_Random vs. KCNJ2_MOUSE_EvolvePro: t-test paired samples, P_val:nan t=nan
# KCNJ2_MOUSE_EvolvePro vs. KCNJ2_MOUSE_FolDE: t-test paired samples, P_val:1.079e-02 t=-3.203e+00
# KKA2_KLEPN_Random vs. KKA2_KLEPN_EvolvePro: t-test paired samples, P_val:nan t=nan
# KKA2_KLEPN_EvolvePro vs. KKA2_KLEPN_FolDE: t-test paired samples, P_val:8.230e-06 t=-9.041e+00
# LGK_LIPST_Random vs. LGK_LIPST_EvolvePro: t-test paired samples, P_val:nan t=nan
# LGK_LIPST_EvolvePro vs. LGK_LIPST_FolDE: t-test paired samples, P_val:5.499e-08 t=-1.629e+01
# MET_HUMAN_Random vs. MET_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# MET_HUMAN_EvolvePro vs. MET_HUMAN_FolDE: t-test paired samples, P_val:6.154e-06 t=-9.366e+00
# MK01_HUMAN_Random vs. MK01_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# MK01_HUMAN_EvolvePro vs. MK01_HUMAN_FolDE: t-test paired samples, P_val:1.516e-02 t=-2.992e+00
# MTHR_HUMAN_Random vs. MTHR_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# ADRB2_HUMAN_Random vs. ADRB2_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# ADRB2_HUMAN_EvolvePro vs. ADRB2_HUMAN_FolDE: t-test paired samples, P_val:6.817e-08 t=-1.589e+01
# MTHR_HUMAN_EvolvePro vs. MTHR_HUMAN_FolDE: t-test paired samples, P_val:1.056e-04 t=-6.546e+00
# P53_HUMAN_Null_Random vs. P53_HUMAN_Null_EvolvePro: t-test paired samples, P_val:nan t=nan
# P53_HUMAN_Null_EvolvePro vs. P53_HUMAN_Null_FolDE: t-test paired samples, P_val:1.235e-04 t=-6.412e+00
# P53_HUMAN_WT_Random vs. P53_HUMAN_WT_EvolvePro: t-test paired samples, P_val:nan t=nan
# P53_HUMAN_WT_EvolvePro vs. P53_HUMAN_WT_FolDE: t-test paired samples, P_val:7.296e-06 t=9.174e+00
# PPARG_HUMAN_Random vs. PPARG_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# PPARG_HUMAN_EvolvePro vs. PPARG_HUMAN_FolDE: t-test paired samples, P_val:2.110e-06 t=-1.065e+01
# PTEN_HUMAN_Random vs. PTEN_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# PTEN_HUMAN_EvolvePro vs. PTEN_HUMAN_FolDE: t-test paired samples, P_val:6.034e-05 t=-7.043e+00
# S22A1_HUMAN_Random vs. S22A1_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# S22A1_HUMAN_EvolvePro vs. S22A1_HUMAN_FolDE: t-test paired samples, P_val:1.478e-07 t=-1.454e+01
# SC6A4_HUMAN_Random vs. SC6A4_HUMAN_EvolvePro: t-test paired samples, P_val:nan t=nan
# SC6A4_HUMAN_EvolvePro vs. SC6A4_HUMAN_FolDE: t-test paired samples, P_val:2.827e-07 t=-1.349e+01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Random vs. EvolvePro: t-test paired samples, P_val:2.088e-19 t=-1.041e+01
# EvolvePro vs. FolDE: t-test paired samples, P_val:2.296e-08 t=-5.905e+00
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMIE_PSEAE_Random vs. AMIE_PSEAE_EvolvePro: t-test paired samples, P_val:6.487e-01 t=-4.712e-01
# AMIE_PSEAE_EvolvePro vs. AMIE_PSEAE_FolDE: t-test paired samples, P_val:1.616e-03 t=-4.443e+00
# CAS9_STRP1_Random vs. CAS9_STRP1_EvolvePro: t-test paired samples, P_val:8.643e-01 t=1.758e-01
# CAS9_STRP1_EvolvePro vs. CAS9_STRP1_FolDE: t-test paired samples, P_val:3.436e-02 t=-2.491e+00
# KCNJ2_MOUSE_Random vs. KCNJ2_MOUSE_EvolvePro: t-test paired samples, P_val:6.886e-01 t=-4.139e-01
# KCNJ2_MOUSE_EvolvePro vs. KCNJ2_MOUSE_FolDE: t-test paired samples, P_val:8.732e-03 t=-3.335e+00
# KKA2_KLEPN_Random vs. KKA2_KLEPN_EvolvePro: t-test paired samples, P_val:2.413e-03 t=-4.170e+00
# KKA2_KLEPN_EvolvePro vs. KKA2_KLEPN_FolDE: t-test paired samples, P_val:7.404e-01 t=-3.417e-01
# LGK_LIPST_Random vs. LGK_LIPST_EvolvePro: t-test paired samples, P_val:1.372e-03 t=-4.557e+00
# LGK_LIPST_EvolvePro vs. LGK_LIPST_FolDE: t-test paired samples, P_val:1.214e-03 t=-4.643e+00
# MET_HUMAN_Random vs. MET_HUMAN_EvolvePro: t-test paired samples, P_val:1.915e-03 t=-4.326e+00
# MET_HUMAN_EvolvePro vs. MET_HUMAN_FolDE: t-test paired samples, P_val:7.773e-01 t=-2.915e-01
# MK01_HUMAN_Random vs. MK01_HUMAN_EvolvePro: t-test paired samples, P_val:2.194e-01 t=-1.320e+00
# MK01_HUMAN_EvolvePro vs. MK01_HUMAN_FolDE: t-test paired samples, P_val:7.682e-02 t=-1.998e+00
# MTHR_HUMAN_Random vs. MTHR_HUMAN_EvolvePro: t-test paired samples, P_val:4.805e-03 t=-3.715e+00
# ADRB2_HUMAN_Random vs. ADRB2_HUMAN_EvolvePro: t-test paired samples, P_val:7.917e-04 t=-4.950e+00
# ADRB2_HUMAN_EvolvePro vs. ADRB2_HUMAN_FolDE: t-test paired samples, P_val:7.716e-04 t=-4.968e+00
# MTHR_HUMAN_EvolvePro vs. MTHR_HUMAN_FolDE: t-test paired samples, P_val:2.131e-01 t=-1.340e+00
# P53_HUMAN_Null_Random vs. P53_HUMAN_Null_EvolvePro: t-test paired samples, P_val:3.001e-05 t=-7.700e+00
# P53_HUMAN_Null_EvolvePro vs. P53_HUMAN_Null_FolDE: t-test paired samples, P_val:1.640e-01 t=1.515e+00
# P53_HUMAN_WT_Random vs. P53_HUMAN_WT_EvolvePro: t-test paired samples, P_val:1.105e-01 t=1.770e+00
# P53_HUMAN_WT_EvolvePro vs. P53_HUMAN_WT_FolDE: t-test paired samples, P_val:4.838e-01 t=-7.303e-01
# PPARG_HUMAN_Random vs. PPARG_HUMAN_EvolvePro: t-test paired samples, P_val:2.992e-04 t=-5.687e+00
# PPARG_HUMAN_EvolvePro vs. PPARG_HUMAN_FolDE: t-test paired samples, P_val:1.726e-03 t=-4.398e+00
# PTEN_HUMAN_Random vs. PTEN_HUMAN_EvolvePro: t-test paired samples, P_val:1.225e-03 t=-4.636e+00
# PTEN_HUMAN_EvolvePro vs. PTEN_HUMAN_FolDE: t-test paired samples, P_val:5.012e-01 t=-7.007e-01
# S22A1_HUMAN_Random vs. S22A1_HUMAN_EvolvePro: t-test paired samples, P_val:1.949e-05 t=-8.128e+00
# S22A1_HUMAN_EvolvePro vs. S22A1_HUMAN_FolDE: t-test paired samples, P_val:2.021e-03 t=-4.290e+00
# SC6A4_HUMAN_Random vs. SC6A4_HUMAN_EvolvePro: t-test paired samples, P_val:2.223e-04 t=-5.924e+00
# SC6A4_HUMAN_EvolvePro vs. SC6A4_HUMAN_FolDE: t-test paired samples, P_val:2.195e-01 t=1.320e+00
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Random vs. EvolvePro: t-test paired samples, P_val:1.776e-23 t=-1.194e+01
# EvolvePro vs. FolDE: t-test paired samples, P_val:9.011e-06 t=-4.599e+00
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMIE_PSEAE_Random vs. AMIE_PSEAE_EvolvePro: t-test paired samples, P_val:2.456e-02 t=-2.696e+00
# AMIE_PSEAE_EvolvePro vs. AMIE_PSEAE_FolDE: t-test paired samples, P_val:1.323e-02 t=-3.076e+00
# CAS9_STRP1_Random vs. CAS9_STRP1_EvolvePro: t-test paired samples, P_val:5.596e-01 t=-6.058e-01
# CAS9_STRP1_EvolvePro vs. CAS9_STRP1_FolDE: t-test paired samples, P_val:3.056e-01 t=-1.086e+00
# KCNJ2_MOUSE_Random vs. KCNJ2_MOUSE_EvolvePro: t-test paired samples, P_val:6.515e-01 t=-4.672e-01
# KCNJ2_MOUSE_EvolvePro vs. KCNJ2_MOUSE_FolDE: t-test paired samples, P_val:6.352e-03 t=-3.536e+00
# KKA2_KLEPN_Random vs. KKA2_KLEPN_EvolvePro: t-test paired samples, P_val:2.972e-03 t=-4.030e+00
# KKA2_KLEPN_EvolvePro vs. KKA2_KLEPN_FolDE: t-test paired samples, P_val:1.487e-01 t=-1.579e+00
# LGK_LIPST_Random vs. LGK_LIPST_EvolvePro: t-test paired samples, P_val:6.229e-04 t=-5.126e+00
# LGK_LIPST_EvolvePro vs. LGK_LIPST_FolDE: t-test paired samples, P_val:6.238e-05 t=-7.012e+00
# MET_HUMAN_Random vs. MET_HUMAN_EvolvePro: t-test paired samples, P_val:3.535e-04 t=-5.556e+00
# MET_HUMAN_EvolvePro vs. MET_HUMAN_FolDE: t-test paired samples, P_val:4.381e-01 t=8.114e-01
# MK01_HUMAN_Random vs. MK01_HUMAN_EvolvePro: t-test paired samples, P_val:1.140e-01 t=-1.750e+00
# MK01_HUMAN_EvolvePro vs. MK01_HUMAN_FolDE: t-test paired samples, P_val:4.020e-01 t=-8.795e-01
# MTHR_HUMAN_Random vs. MTHR_HUMAN_EvolvePro: t-test paired samples, P_val:5.076e-04 t=-5.279e+00
# ADRB2_HUMAN_Random vs. ADRB2_HUMAN_EvolvePro: t-test paired samples, P_val:3.256e-02 t=-2.524e+00
# ADRB2_HUMAN_EvolvePro vs. ADRB2_HUMAN_FolDE: t-test paired samples, P_val:1.181e-02 t=-3.146e+00
# MTHR_HUMAN_EvolvePro vs. MTHR_HUMAN_FolDE: t-test paired samples, P_val:3.389e-01 t=1.010e+00
# P53_HUMAN_Null_Random vs. P53_HUMAN_Null_EvolvePro: t-test paired samples, P_val:4.761e-06 t=-9.662e+00
# P53_HUMAN_Null_EvolvePro vs. P53_HUMAN_Null_FolDE: t-test paired samples, P_val:3.626e-02 t=2.458e+00
# P53_HUMAN_WT_Random vs. P53_HUMAN_WT_EvolvePro: t-test paired samples, P_val:4.951e-01 t=7.110e-01
# P53_HUMAN_WT_EvolvePro vs. P53_HUMAN_WT_FolDE: t-test paired samples, P_val:2.264e-01 t=1.299e+00
# PPARG_HUMAN_Random vs. PPARG_HUMAN_EvolvePro: t-test paired samples, P_val:7.714e-05 t=-6.822e+00
# PPARG_HUMAN_EvolvePro vs. PPARG_HUMAN_FolDE: t-test paired samples, P_val:9.564e-02 t=-1.861e+00
# PTEN_HUMAN_Random vs. PTEN_HUMAN_EvolvePro: t-test paired samples, P_val:8.665e-05 t=-6.719e+00
# PTEN_HUMAN_EvolvePro vs. PTEN_HUMAN_FolDE: t-test paired samples, P_val:1.929e-01 t=-1.407e+00
# S22A1_HUMAN_Random vs. S22A1_HUMAN_EvolvePro: t-test paired samples, P_val:3.667e-05 t=-7.507e+00
# S22A1_HUMAN_EvolvePro vs. S22A1_HUMAN_FolDE: t-test paired samples, P_val:6.116e-04 t=-5.140e+00
# SC6A4_HUMAN_Random vs. SC6A4_HUMAN_EvolvePro: t-test paired samples, P_val:8.027e-04 t=-4.940e+00
# SC6A4_HUMAN_EvolvePro vs. SC6A4_HUMAN_FolDE: t-test paired samples, P_val:9.877e-01 t=1.589e-02
