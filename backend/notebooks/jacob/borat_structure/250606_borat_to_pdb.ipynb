# %%
from app.jobs.boltz_jobs import cif_to_pdb

pdb_file_contents = cif_to_pdb('notebooks/jacob/fold_2025_06_06_15_04_borat_model_0.cif', 'structure')

# %%
with open('notebooks/jacob/fold_2025_06_06_15_04_borat_model_0.pdb', 'w') as f:
    f.write(pdb_file_contents)
