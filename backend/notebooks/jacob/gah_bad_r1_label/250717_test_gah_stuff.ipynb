# %%
import pandas as pd

r1_pred_activities = pd.read_csv('notebooks/jacob/gah_bad_r1_label/r1_constantliarS2_3_predicted_activity.csv')

# %%
r1_pred_activities['mean'] = r1_pred_activities[['model_0', 'model_1', 'model_2', 'model_3', 'model_4']].mean(axis=1)

# %%
r1_pred_activities = r1_pred_activities.sort_values(by='mean', ascending=False).reset_index(drop=True)
r1_pred_activities.iloc[3].relevant_measured_mutants
# Out:
# 'G361S, S189L, S189L_F301C, S189L_F301V, S23T_S189I, S23T_S189I'

# %%
r1_pred_activities[r1_pred_activities.seq_id.isin('''N35K_S76Y_L294P_A378T
M417L_L420E
S76Y_L294P_A378T_M417V
S76Y_C238K_L294P_A378T
S76Y_L294P_A378T_F427S
S76Y_M105R_L294P_A378T
S76Y_L294P_L320K_A378T
S76Y_C242K_L294P_A378T
S76Y_C238S_L294P_A378T
S23T_M105E_S189L
S23T_S189L_C238E
S76Y_L294P_M308T_A378T
S76Y_M105E_L294P_A378T
S76Y_C238E_L294P_A378T
S76Y_L294P_A378T_H386E
S76Y_L294P_A378T_H386R
S76Y_L294P_A378T_L420K
S76Y_L294P_A378T_H386K
S76Y_M105K_L294P_A378T
S76Y_H273K_L294P_A378T
S76Y_C238T_L294P_A378T
S76Y_L294P_A378T_F427K
S76Y_C242T_L294P_A378T
S23T_S189L_C238K'''.split('\n'))]
# Out:
#                       seq_id   model_0   model_1   model_2   model_3  \
# 2     S76Y_M105E_L294P_A378T  3.088921  2.545112  3.327572  2.999376
# 14          S23T_M105E_S189L  2.964729  2.060224  2.528527  2.894932
# 24          S23T_S189L_C238K  2.856276  2.097561  2.830424  2.663487
# 41    S76Y_C242K_L294P_A378T  2.213236  2.405601  3.150005  2.424740
# 42    S76Y_C238K_L294P_A378T  2.478912  2.364798  2.753351  2.651266
# 50    S76Y_C238E_L294P_A378T  2.439864  2.486370  2.419768  2.516902
# 51    S76Y_M105K_L294P_A378T  2.563441  2.067829  2.612280  2.454938
# 61    S76Y_C238T_L294P_A378T  2.389224  2.193855  2.755972  2.579171
# 63          S23T_S189L_C238E  2.676477  2.130433  2.358984  2.385702
# 68    S76Y_C238S_L294P_A378T  2.470734  2.314911  2.546851  2.420143
# 79    S76Y_L294P_A378T_F427K  2.200324  2.271146  2.533580  2.397817
# 84    S76Y_L294P_A378T_H386E  2.448131  2.165534  2.380292  2.441718
# 101   S76Y_M105R_L294P_A378T  2.476571  2.082374  2.411001  2.177814
# ...
