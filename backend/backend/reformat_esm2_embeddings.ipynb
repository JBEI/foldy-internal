# %%
import pandas as pd

# %%
import pathlib
pathlib.Path('.').absolute()
# Out:
# WindowsPath('c:/Users/ese/foldy/backend/src')

# %%
df = pd.read_csv(r'..\EvolveTest\kelsic_esm2_t33_650M_UR50D.csv')

# %%
import json
df['embedding'] = df[df.columns[1:]].apply(lambda r: json.dumps(list(r)), axis=1)

# %%
df.rename(columns={'Unnamed: 0': 'seq_id'})[['seq_id', 'embedding']]\
    .to_csv(r'..\EvolveTest\kelsic_esm2_t33_650M_UR50D_reformat.csv', index=False)
